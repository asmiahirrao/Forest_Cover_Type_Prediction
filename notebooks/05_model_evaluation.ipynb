# %%
import joblib
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Load model
model = joblib.load('C:/Users/aahir/OneDrive/Desktop/random_forest_model.pkl')

# Load X_test
X_test = joblib.load('C:/Users/aahir/OneDrive/Desktop/X_test.pkl')

# Load y_test
y_test = joblib.load('C:/Users/aahir/OneDrive/Desktop/y_test.pkl')

# Make predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Classification report
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.savefig('C:/Users/aahir/OneDrive/Desktop/confusion_matrix.png')
plt.show()

# Feature Importance
feature_importances = model.feature_importances_
sorted_idx = np.argsort(feature_importances)

# Create a horizontal bar plot for feature importance
plt.barh(np.arange(len(feature_importances)), feature_importances[sorted_idx], color='teal')
plt.xlabel("Random Forest Feature Importance")
plt.title("Feature Importance")
plt.show()
# Out:
# Accuracy: 0.8753306878306878
#               precision    recall  f1-score   support
#
#            1       0.78      0.78      0.78       421
#            2       0.81      0.69      0.75       438
#            3       0.87      0.84      0.85       428
#            4       0.93      0.98      0.96       449
#            5       0.90      0.95      0.92       416
#            6       0.87      0.90      0.88       432
#            7       0.95      0.97      0.96       440
#
#     accuracy                           0.88      3024
#    macro avg       0.87      0.87      0.87      3024
# weighted avg       0.87      0.88      0.87      3024
